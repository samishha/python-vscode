# %%
# !python -m pip install opencv-python
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !python -m pip install scikit-image
# Out:
# ...
#      ---------------------------------------- 23.7/23.7 MB 3.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 42.2/42.2 MB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.1/2.1 MB 3.5 MB/s eta 0:00:00
# ...
#   Using cached Pillow-9.5.0-cp311-cp311-win_amd64.whl (2.5 MB)
# ...
#      ---------------------------------------- 3.4/3.4 MB 3.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 219.4/219.4 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.2/4.2 MB 2.5 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !python -m pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.7.1-cp311-cp311-win_amd64.whl (7.6 MB)
# ...
#   Using cached contourpy-1.0.7-cp311-cp311-win_amd64.whl (162 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached fonttools-4.39.3-py3-none-any.whl (1.0 MB)
# ...
#   Using cached kiwisolver-1.4.4-cp311-cp311-win_amd64.whl (55 kB)
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# Image Processing & computer Vision: Prj-1
# digital image: unsigned integer{0 - 255}
# types of image:      1 true color image(standard color - RGB)
#                      2 greyscale
#                      3 binary

# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
img = cv2.imread('wth.jfif')
cv2.imshow('', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
img
# Out:
# array([[[247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247],
#         ...,
#         [247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247]],
#
#        [[247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247],
#         ...,
#         [247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247]],
#
#        [[247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247],
#         ...,
#         [247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247]],
#
#        ...,
#
#        [[247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247],
#         ...,
#         [247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247]],
#
#        [[247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247],
#         ...,
#         [247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247]],
#
#        [[247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247],
# ...

# %%
img1 = plt.imread('wth.jfif')
plt.imshow(img1)
